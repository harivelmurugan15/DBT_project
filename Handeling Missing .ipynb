# %%
import pandas as pd

df = pd.read_excel(r"C:\Users\ASUS\Downloads\Sample Data file for Analysis_Jan'25.xlsx")
df
# Out:
#                                inc_business_service             inc_category  \
# 0     GRP56.34 PRXX (DigitalC Workplace management)         Business Service
# 1     GRP56.34 PRXX (DigitalC Workplace management)         Business Service
# 2            NxGen Tech. Business SErvices - Backup  Hardware-Infrastructure
# 3            NxGen Tech. Business SErvices - Backup  Hardware-Infrastructure
# 4            NxGen Tech. Business SErvices - Backup  Hardware-Infrastructure
# ...                                             ...                      ...
# 4994                               L1/LO L3 Support                 Software
# 4995                               L1/LO L3 Support                 Software
# 4996                               L1/LO L3 Support                 Software
# 4997                               L1/LO L3 Support                 Software
# 4998                               L1/LO L3 Support                 Software
#
#        inc_number  inc_priority inc_sla_due  inc_sys_created_on  \
# 0       I68793614  3 - Moderate     UNKNOWN 2018-10-03 00:00:36
# 1       I68793614  3 - Moderate     UNKNOWN 2018-10-03 00:00:36
# 2       I68793615  3 - Moderate     UNKNOWN 2018-10-03 00:01:38
# 3       I68793615  3 - Moderate     UNKNOWN 2018-10-03 00:01:38
# 4       I68793616  3 - Moderate     UNKNOWN 2018-10-03 00:21:33
# ...           ...           ...         ...                 ...
# 4994  ic678576982  3 - Moderate     UNKNOWN 2018-10-04 10:20:45
# 4995  ic678576982  3 - Moderate     UNKNOWN 2018-10-04 10:20:45
# 4996  ic678576972  3 - Moderate     UNKNOWN 2018-10-04 10:20:45
# 4997  ic678576972  3 - Moderate     UNKNOWN 2018-10-04 10:20:45
# 4998  ic678576972  3 - Moderate     UNKNOWN 2018-10-04 10:20:45
#
#          inc_resolved_at             inc_assigned_to inc_state  \
# 0    2018-10-03 10:00:39  sn int-test-svc Functional    Closed
# 1    2018-10-03 10:00:39                 Emily White    Closed
# 2    2018-10-03 00:16:32          prd-sql Functional    Closed
# 3    2018-10-03 00:16:32                Grace Harris    Closed
# 4    2018-10-03 01:36:27               Jack Mitchell    Closed
# ...                  ...                         ...       ...
# 4994 2018-10-05 20:50:54                   Zoe Green    Closed
# 4995 2018-10-05 20:50:54                  Jack Green    Closed
# 4996 2018-10-06 08:02:08                Samuel Young    Closed
# 4997 2018-10-06 08:02:08                  Ruby White    Closed
# 4998 2018-10-06 08:02:08                Benjamin Lee    Closed
#
#                                         inc_cmdb_ci       inc_caller_id  \
# 0     GRP56.34 PRXX (DigitalC Workplace management)   Event Management
# 1     GRP56.34 PRXX (DigitalC Workplace management)   Event Management
# 2                                               NaN   Event Management
# 3                                               NaN   Event Management
# 4                                               NaN   Event Management
# ...                                             ...                 ...
# 4994                        Process Reorder Service  ITSM-PO Functional
# 4995                        Process Reorder Service  ITSM-PO Functional
# 4996                        Process Reorder Service  ITSM-PO Functional
# 4997                        Process Reorder Service  ITSM-PO Functional
# 4998                        Process Reorder Service  ITSM-PO Functional
#
#                                   inc_short_description  \
# 0     Monitor status is error for ukwwnppcm0981_[PCM...
# 1     Monitor status is error for ukwwnppcm0981_[PCM...
# 2     IND01PXXRBK01: NBR: OracleDb:Backup : Status: ...
# 3     IND01PXXRBK01: NBR: OracleDb:Backup : Status: ...
# 4     IND01PXXRBK01: SLQ: OracleDb:Backup : Status: ...
# ...                                                 ...
# 4994            Error reported by alert rule 'AR_C142a'
# 4995            Error reported by alert rule 'AR_C142a'
# 4996            Error reported by alert rule 'AR_C142d'
# 4997            Error reported by alert rule 'AR_C142d'
# 4998            Error reported by alert rule 'AR_C142d'
#
#          inc_assignment_group     inc_close_code  \
# 0     EngineeringSystems-Lev2    3rd Party Issue
# 1     EngineeringSystems-Lev2    3rd Party Issue
# 2          Bakup_Tek-SVC-Lev2  Other not on list
# 3          Bakup_Tek-SVC-Lev2  Other not on list
# 4          Bakup_Tek-SVC-Lev2  Other not on list
# ...                       ...                ...
# 4994           SFA-PI-PO-Lev2      Network Issue
# 4995           SFA-PI-PO-Lev2      Network Issue
# 4996           SFA-PI-PO-Lev2      Network Issue
# 4997           SFA-PI-PO-Lev2      Network Issue
# 4998           SFA-PI-PO-Lev2      Network Issue
#
#                                         inc_close_notes
# 0                       Covered in Problem management.
# 1                       Covered in Problem management.
# 2                               Resolving from CliqApps
# 3                               Resolving from CliqApps
# 4                               Resolving from CliqApps
# ...                                                 ...
# 4994  Closure - Alerts triggered due to CHIP downtim...
# 4995  Closure - Alerts triggered due to CHIP downtim...
# 4996  _x000D_\nAlerts triggered due to CHIP downtime...
# 4997  _x000D_\nAlerts triggered due to CHIP downtime...
# 4998  _x000D_\nAlerts triggered due to CHIP downtime...
#
# [4999 rows x 15 columns]

# %%
# !pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\ASUS\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
df.shape
# Out:
# (4999, 15)

# %%
df.dtypes
# Out:
# inc_business_service             object
# inc_category                     object
# inc_number                       object
# inc_priority                     object
# inc_sla_due                      object
# inc_sys_created_on       datetime64[ns]
# inc_resolved_at          datetime64[ns]
# inc_assigned_to                  object
# inc_state                        object
# inc_cmdb_ci                      object
# inc_caller_id                    object
# inc_short_description            object
# inc_assignment_group             object
# inc_close_code                   object
# inc_close_notes                  object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4999 entries, 0 to 4998
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   inc_business_service   4999 non-null   object
#  1   inc_category           4999 non-null   object
#  2   inc_number             4999 non-null   object
#  3   inc_priority           4999 non-null   object
#  4   inc_sla_due            4999 non-null   object
#  5   inc_sys_created_on     4999 non-null   datetime64[ns]
#  6   inc_resolved_at        4886 non-null   datetime64[ns]
#  7   inc_assigned_to        4999 non-null   object
#  8   inc_state              4999 non-null   object
#  9   inc_cmdb_ci            3911 non-null   object
#  10  inc_caller_id          4999 non-null   object
#  11  inc_short_description  4997 non-null   object
#  12  inc_assignment_group   4999 non-null   object
#  13  inc_close_code         4886 non-null   object
#  14  inc_close_notes        4877 non-null   object
# dtypes: datetime64[ns](2), object(13)
# memory usage: 585.9+ KB

# %%
df.isnull().sum()
# Out:
# inc_business_service        0
# inc_category                0
# inc_number                  0
# inc_priority                0
# inc_sla_due                 0
# inc_sys_created_on          0
# inc_resolved_at           113
# inc_assigned_to             0
# inc_state                   0
# inc_cmdb_ci              1088
# inc_caller_id               0
# inc_short_description       2
# inc_assignment_group        0
# inc_close_code            113
# inc_close_notes           122
# dtype: int64

# %%
df.isnull().mean()*100
# Out:
# inc_business_service      0.000000
# inc_category              0.000000
# inc_number                0.000000
# inc_priority              0.000000
# inc_sla_due               0.000000
# inc_sys_created_on        0.000000
# inc_resolved_at           2.260452
# inc_assigned_to           0.000000
# inc_state                 0.000000
# inc_cmdb_ci              21.764353
# inc_caller_id             0.000000
# inc_short_description     0.040008
# inc_assignment_group      0.000000
# inc_close_code            2.260452
# inc_close_notes           2.440488
# dtype: float64

# %%
df.describe(include="object")
# Out:
#            inc_business_service inc_category   inc_number  inc_priority  \
# count                      4999         4999         4999          4999
# unique                      202            9         1870             4
# top     CRM Operational Support     Software  ic678576043  3 - Moderate
# freq                       1362         3488          210          2658
#
#        inc_sla_due inc_assigned_to inc_state              inc_cmdb_ci  \
# count         4999            4999      4999                     3911
# unique           1             456         5                      304
# top        UNKNOWN        Mia King    Closed  Process Reorder Service
# freq          4999              51      4886                      786
#
#              inc_caller_id                              inc_short_description  \
# count                 4999                                               4997
# unique                   3                                               1493
# top     Cross-Connect  svc  IND01DWISD101: _Total: Memory : % Used Memory:...
# freq                  2836                                                210
#
#        inc_assignment_group     inc_close_code          inc_close_notes
# count                  4999               4886                     4877
# unique                  181                 21                     1029
# top          SFA-PI-PO-Lev2  Other not on list  Resolving from CliqApps
# freq                    786               1801                      673

# %%
df.duplicated().sum()
# Out:
# np.int64(46)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['inc_business_service', 'inc_category', 'inc_number', 'inc_priority',
#        'inc_sla_due', 'inc_sys_created_on', 'inc_resolved_at',
#        'inc_assigned_to', 'inc_state', 'inc_cmdb_ci', 'inc_caller_id',
#        'inc_short_description', 'inc_assignment_group', 'inc_close_code',
#        'inc_close_notes'],
#       dtype='object')

# %%
for col in df.columns:
    unique_values = df[col].unique()
    print(f"columns: {col}")
    print(f"Unique Values:{unique_values}")
    print("==="*25)
# Out:
# columns: inc_business_service
# Unique Values:['GRP56.34 PRXX (DigitalC Workplace management)'
#  'NxGen Tech. Business SErvices - Backup'
#  'NxGen Tech. Business SErvices - Windows' 'CRM Operational Support'
#  'Global Service Desk' 'NxGen TechServiceDesk-APAC-NonEnglish'
#  'Advanced Authentication' 'NxGen RPA Application / Bot Support'
#  'PC Hardware' 'MVPTeMVPBI MAVIS Service' 'NxGen MW Support'
#  'NxGen Tech. Business SErvices - MSSQL'
#  'SVC TeMVP- Quality & Support (SMS, MQD)'
#  'NxGen Tech. Business SErvices - Linux' 'PRXXuctivity Applications'
#  'NxGen Remote Application Access' 'NxGen RPA Platform Support'
#  'NxGen Citrix Cloud - US Dev' 'NxGen Tech. Business SErvices - NetTool'
#  'NxGen Buying Goods & Services' 'NxGen Global TeMVPService Desk'
#  'NxGen Wave 0 - Onboarding' 'Value Chain - E2E Visibility'
#  'ISC - Local Applications' 'NxGen CGIT Service' 'Expense Management'
#  'Deskside-Asia-House' 'NxGen Privileged Access Management (PAM) Service'
#  'Connectivity Service' 'Email Services' 'Deskside-Jamshoro-L1'
#  'MVPData Enablement - Data Management Platform - PRXX'
#  'SMBO ServiceNow Ecrystal Triage' 'External Access Services'
#  'Deskside-APAC' 'User Account Management'
#  'MVPteMVPglobal bi service - XAVA' 'NxGen ERP SFA SQMC'
#  'ServiceNow Analytics' 'NxGen Business Applications Tools'
#  'NxGen Document Services'
#  'Perimeter Security & Compliance - Service Offering' 'ERP SFA Workflow'
#  'NxGen DENTURE' 'Directory Services' 'NxGen MS O365'
#  'Global TeMVPService Desk' 'End to End Service Operations (ERP)'
#  'Deskside-Leon-L1' 'NxGen ERP SFA CF Value Lev2 Support'
#  'Deskside-Tres-Cantos-L1' 'Deskside-Bangalore' 'MVPChamps - PRXX'
#  'NxGen HR - ODS / Reorg Services' 'Maidenhead Site Local VC Service'
#  'Applications Monitoring' 'NxGen Travel & Expense'
#  'Business Applications Tools' 'Oracle Support - Global'
#  'NxGen TechServiceDesk-EMEA' 'myLearning Services ' 'Deskside-Marisa'
#  'MVPC&C - SFA (First SFA Pharmacy & Mass)' 'Azure RBAC Roles Backup'
#  'Deskside-Peringan-L1' 'Bitwarden Platform - RETIRED' 'Mobile Devices UK'
#  'MVPCompass Service' 'Wireless' 'Cryptographic Key Service'
#  'End to End Service Operations (Non-ERP)'
#  'Deskside-Poznan-Business-Garden-L1' 'NxGen Finance Ops & Analytics'
#  'NxGen Microsoft O365 OneDrive For Business'
#  'Multi Function Device (MFD) Consumables and First Fix Services'
#  'NxGen File Sharing' 'Agile Tooling Platform Business Service'
#  'CASH Analytics' 'NxGen ERP SFA Security' 'Deskside-Dungarvan'
#  'Deskside-Athens' 'Deskside-Thailand' 'ERP User Support'
#  'active directory service for consumer healthcare - IT (ad.Svcnet.org)'
#  'Deskside-Moscow-L1' 'NxGen Adobe Document and Creative Cloud'
#  'L1/LO L3 Support' 'Deskside-DubaiArenco' 'Pulse Secure VPN/StaffConnect'
#  'Deskside-Pulogadung-L1' 'NxGen H2R - Workforce Management'
#  'REPMSV Platform' 'Deskside-Prague-L1' 'Deskside-Maidenhead-L1'
#  'NxGen DevSecOps' 'Ariba Queries' 'Purchase to Pay Help'
#  'windows deployment service' 'NxGen Serialization'
#  'MVPchamps - gxp service' 'Printer / File Shre'
#  'NxGen Expnce Expense Management - PRXX'
#  'Serialisation – Business Process' 'Deskside-India-Gurgaon'
#  'R&D TeMVPLab Engineering' 'Dungarvan - Deskside - IT'
#  'PC Application Catalog and Installation' 'SMBO Platform - Core'
#  'Deskside-Cairo' 'NxGen SFA BW Lev2 Support' 'Dungarvan Automation'
#  'NxGen Collaboration & PRXXuctivity' 'Ricoh Streamline Pull Print'
#  'NxGen Email Services' 'MVPTeMVPGlobal Power Platform'
#  'Value Chain - NPI, Pack and Portfolio' 'PC Build'
#  'Deskside-Karachi West Wharf-L1' 'Security Infrastructure'
#  'Deskside-Levice-L1' 'SVC TeMVP- Lab Operations (LABC21, SLIMS)'
#  'SLIMS - PRXX' 'NxGen HR - Services & Benefits'
#  'Guayama Site Local VC Service : P056546201' 'Deskside-missisuaga-L1'
#  'Guayama Site Local SLIMS LAB : S074359865' 'Global Print Services'
#  'Deskside-Baranzate' 'ERP SFA Op. Finance Lev2 Support' 'Deskside-Alcala'
#  'Deskside-Nairobi-L1' 'Leaving ABV' 'Data Services'
#  'NxGen Legal & eDiscovery Services' 'NxGen Microsoft O365 SharePoint'
#  'Deskside-Warsaw-Cirrus-L1' 'Deskside-Santiago-L1' 'Modern Workspace'
#  'Deskside-Lincoln-L1' 'Collaboration' 'MVPC&C - Content Excellence'
#  'Deskside-Chennai-L1' 'NxGen PC Application Catalog and Installation'
#  'MVPC&C - Consumer Relations Management System'
#  'Collab, Social & Broadcast Service' 'Deskside-Guayama'
#  'Value Chain - Manufacturing Execution' 'NxGen New Fileshare'
#  'Pas-X EBRS' 'NxGen TechServiceDesk-Global-English'
#  'CRS (Customer Relation Services) BT Telephony' 'NxGen SFA BW L3 Support'
#  'Perimeter Security & Compliance' 'Secure File Transfer (SFT)'
#  'Guayama Site Local ONECDS LAB : S074359866'
#  'NxGen Gerp Qlik Sense Application  - Dev' 'APOLLO OTIF' 'Stibo MDM'
#  'SMBO Platform - Request Management' 'ERP SFA TSM Support'
#  'NxGen Platform-API' 'PC PRXXucts' 'Deskside-Civac'
#  'MVPExpert First SFA US' 'HR for Employees'
#  'Guayama Site Local LAB : S074358036' 'Records Retention'
#  'NxGen ERP SFA Basis PRXX Support' 'Master Data Management'
#  'Deskside-Noida-L1' 'ERP SFA Basis PRXX Support' 'Deskside-CapeTown'
#  'Deskside-TerraCampus-L1' 'Deskside-Buenos-Aires' 'Deskside-Panama-L1'
#  'Support TSK' 'Deskside-Lima-L1' 'FSO-Dispatch' 'CMMS EAM MVPPRXX'
#  'global data services' 'Mobile Devices' 'Deskside-Nagpur-L1'
#  'Global ERP Service Management' 'MVPRMS Dashboard- PRXXuction'
#  'Azure Analytics Quality Dashboard PRXX' 'Deskside-Seoul-L1'
#  'Proximity Gateway' 'Data Platform and Solutions'
#  'Master Data Management Services' 'Asset and Configuration Management'
#  'NxGen Employee Services' 'Deskside-Istanbul-L1' 'NxGen Mobility Service'
#  'Identity Services' 'NxGen Streamlinenx PRXX Apac'
#  'Leon Site Local VC Service' 'NxGen WMAS Services'
#  'NxGen Platform Services' 'NxGen ERP SFA TSM Support'
#  'NxGen Tech. Business SErvices - Azure' 'Firewall'
#  'SFA Fieldglass-Internal Tech']
# ===========================================================================
# columns: inc_category
# Unique Values:['Business Service' 'Hardware-Infrastructure' 'Software' 'Network'
#  'Workstation' 'Finance' 'Collaboration' 'Facilities' 'Hardware']
# ===========================================================================
# columns: inc_number
# Unique Values:['I68793614' 'I68793615' 'I68793616' ... 'ic678576983' 'ic678576982'
#  'ic678576972']
# ===========================================================================
# columns: inc_priority
# Unique Values:['3 - Moderate' '2 - High' '4 - Low' '1 - Critical']
# ===========================================================================
# columns: inc_sla_due
# Unique Values:['UNKNOWN']
# ===========================================================================
# columns: inc_sys_created_on
# Unique Values:<DatetimeArray>
# ['2018-10-03 00:00:36', '2018-10-03 00:01:38', '2018-10-03 00:21:33',
#  '2018-10-03 00:26:41', '2018-10-03 00:30:12', '2018-10-03 00:31:36',
#  '2018-10-03 00:34:42', '2018-10-03 00:36:38', '2018-10-03 00:42:25',
#  '2018-10-03 01:04:19',
#  ...
#  '2018-10-04 10:17:52', '2018-10-04 10:18:32', '2018-10-04 10:19:10',
#  '2018-10-04 10:20:39', '2018-10-04 10:20:40', '2018-10-04 10:20:41',
#  '2018-10-04 10:20:42', '2018-10-04 10:20:43', '2018-10-04 10:20:44',
#  '2018-10-04 10:20:45']
# Length: 1676, dtype: datetime64[ns]
# ===========================================================================
# columns: inc_resolved_at
# Unique Values:<DatetimeArray>
# ['2018-10-03 10:00:39', '2018-10-03 00:16:32', '2018-10-03 01:36:27',
#  '2018-10-03 00:41:28', '2018-10-03 11:17:00', '2018-10-03 04:13:16',
#  '2018-10-03 00:51:26', '2018-10-03 02:07:23', '2018-10-03 01:31:27',
#  '2018-10-03 00:47:51',
#  ...
#  '2018-10-05 06:53:34', '2018-10-06 09:23:27', '2018-10-05 18:38:52',
#  '2018-10-06 15:17:57', '2018-10-04 11:23:43', '2018-10-06 15:18:48',
#  '2018-10-06 08:23:54', '2018-10-05 18:45:27', '2018-10-05 20:50:54',
#  '2018-10-06 08:02:08']
# Length: 1822, dtype: datetime64[ns]
# ===========================================================================
# columns: inc_assigned_to
# Unique Values:['sn int-test-svc Functional' 'Emily White' 'prd-sql Functional'
#  'Grace Harris' 'Jack Mitchell' 'Amelia Johnson' 'Robert Davis'
#  'Lily Adams' 'Samuel Clark' 'Zoe Allen' 'David White' 'Mia Scott'
#  'Charlie Cooper' 'Emma Lewis' 'William Wright' 'Abigail Nelson'
#  'Matthew Green' 'Lucy Harris' 'Joseph Young' 'Sophia Lee' 'Michael Evans'
#  'Charlotte Wright' 'Daniel Brown' 'Isla Walker' 'Lucas Lewis'
#  'Emily Roberts' 'Oliver Davis' 'Grace Bennett' 'Nathan Cooper'
#  'Mia Turner' 'Thomas Green' 'Nora Adams' 'Benjamin Hill' 'Ava Cooper'
#  'Jack Young' 'Lily Taylor' 'Oscar Wright' 'Chloe Harris' 'Ethan Cooper'
#  'Ruby Lee' 'George Clark' 'Sophia Parker' 'Jack Evans' 'Abigail Brown'
#  'Daniel Miller' 'Ella Wright' 'William Turner' 'Isabella Allen'
#  'Nathan White' 'Zoe Moore' 'Matthew Young' 'Charlotte Evans'
#  'Lucas Bennett' 'Grace Mitchell' 'Harrison Scott' 'Sophie Lee'
#  'Benjamin Moore' 'Olivia Green' 'James Parker' 'Lily Harris'
#  'David Walker' 'Mia Mitchell' 'Henry Brown' 'Abigail Young'
#  'Thomas Moore' 'Isla Davis' 'Samuel White' 'Emily Cooper' 'Noah Lee'
#  'Violet Parker' 'Daniel Allen' 'Mia White' 'Liam Turner' 'Lucy Walker'
#  'Oscar Green' 'Olivia Davis' 'Lucas Scott' 'Zoe White' 'James Young'
#  'Grace Cooper' 'Benjamin Taylor' 'Lily Young' 'Nathan King'
#  'Charlotte Green' 'Samuel Lewis' 'Emma White' 'Max Wright' 'Abigail Lee'
#  'Benjamin Harris' 'Sophie White' 'David Taylor' 'Emily Green'
#  'Robert Cooper' 'Mia King' 'Oscar Lee' 'Ethan Harris' 'Ella Johnson'
#  'Benjamin White' 'Lily Scott' 'Ruby Turner' 'James Scott' 'Ava King'
#  'Lucas Taylor' 'Grace Allen' 'Michael King' 'Sophie Harris'
#  'William Green' 'Charlotte Young' 'Oscar Harris' 'Ruby Cooper'
#  'David Brown' 'Isla Turner' 'Benjamin Parker' 'Ava Harris' 'Lily Allen'
#  'Liam Scott' 'Charlotte Lee' 'George King' 'Amelia Green' 'Samuel Harris'
#  'Emily King' 'Isaac White' 'Zoe Walker' 'Robert Lewis' 'Lily Green'
#  'Harper Cooper' 'Daniel Davis' 'Sophia King' 'Olivia Harris'
#  'Oscar Turner' 'Emily Bennett' 'William Mitchell' 'Ethan Johnson'
#  'Zoe Taylor' 'Charlie White' 'Mia Brown' 'Daniel Green' 'Thomas Allen'
#  'Ava Scott' 'James Harris' 'Sophie Taylor' 'Liam Walker' 'Grace King'
#  'Benjamin Turner' 'Lily Parker' 'Samuel Taylor' 'Harper White'
#  'Isaac King' 'Olivia Lee' 'Noah Brown' 'Abigail King' 'Edward Turner'
#  'Charlotte Taylor' 'Jack Green' 'Mia Cooper' 'Olivia Mitchell'
#  'Jack Harris' 'Ruby Young' 'Emily Turner' 'Robert Harris' 'Zoe Brown'
#  'Thomas King' 'Lily Davis' 'Nathan Green' 'Benjamin Johnson' 'Ava Brown'
#  'Daniel Taylor' 'Harper Harris' 'James Allen' 'Isla Green' 'William Lee'
#  'Henry Taylor' 'Max White' 'Robert Young' 'Ethan Green' 'Sophia Walker'
#  'James Lee' 'Lily White' 'Oscar Brown' 'Charlotte Cooper' 'Liam Allen'
#  'Ruby Walker' 'Oliver Lee' 'Daniel Scott' 'George White' 'Emily Harris'
#  'Benjamin Mitchell' 'Mia Green' 'Thomas Parker' 'Olivia Brown'
#  'William Harris' 'Abigail Mitchell' 'Samuel Brown' 'Ruby Allen'
#  'Ethan Young' 'Charles Cooper' 'Emma Harris' 'Max Taylor' 'Lily Lee'
#  'Jack Brown' 'Olivia Turner' 'Lucas Harris' 'Harper Green' 'Samuel King'
#  'Benjamin Lee' 'Emily Walker' 'David Green' 'Mia Parker' 'Thomas Lee'
#  'Charlie Walker' 'Lily Cooper' 'Robert White' 'Daniel Parker'
#  'Thomas White' 'Benjamin Green' 'Abigail Parker' 'Noah King'
#  'James Brown' 'Olivia Walker' 'Max Green' 'Sophie Young' 'Liam Taylor'
#  'Charlotte Walker' 'William Brown' 'Ethan Taylor' 'Lily Mitchell'
#  'Benjamin Brown' 'Grace Lee' 'Samuel Green' 'Oscar Scott' 'Zoe King'
#  'Daniel White' 'Liam Mitchell' 'Harper Allen' 'Mia Johnson' 'Lucy White'
#  'Thomas Scott' 'George Harris' 'Abigail Green' 'Jack Lee' 'Oliver Green'
#  'Ruby Taylor' 'William Parker' 'Mia Harris' 'Lucas Green' 'Abigail White'
#  'Ethan Brown' 'Sophie Walker' 'Grace Brown' 'William Taylor'
#  'Oscar Cooper' 'Jack Turner' 'Charlotte Harris' 'Emily Brown'
#  'Sophie King' 'Lucas Turner' 'Robert Lee' 'Ethan Lee' 'Lily Brown'
#  'Noah Turner' 'Thomas Walker' 'Benjamin Walker' 'Oscar Taylor'
#  'Abigail Harris' 'Ethan Walker' 'Emma Young' 'Mia Taylor' 'Lucy Green'
#  'Liam Green' 'Thomas Brown' 'Abigail Walker' 'Oscar White' 'Olivia King'
#  'Sophie Mitchell' 'James Walker' 'Lucy Taylor' 'Daniel King'
#  'Lucy Parker' 'Lily Walker' 'George Green' 'Oscar Allen' 'Abigail Taylor'
#  'James Taylor' 'Sophie Parker' 'Jack White' 'Noah Green' 'Mia Walker'
#  'Oscar King' 'Robert Green' 'Liam Parker' 'Daniel Young' 'Ruby King'
#  'Sophie Green' 'Noah White' 'Mia Lee' 'Grace Taylor' 'Lucas White'
#  'Ethan Allen' 'James King' 'Jack King' 'Samuel Young' 'James White'
#  'Noah Harris' 'Ethan Scott' 'Charlotte White' 'Thomas Taylor'
#  'Charlotte King' 'Olivia Scott' 'Daniel Harris' 'Lucas King' 'Ruby White'
#  'William White' 'Benjamin Allen' 'Lily King' 'James Green' 'Noah Taylor'
#  'Robert Brown' 'Charlotte Brown' 'Ethan King' 'Samuel Walker'
#  'Thomas Young' 'Lucas Walker' 'Grace Green' 'Ruby Parker' 'Oscar Young'
#  'Oscar Parker' 'Zoe Young' 'Ruby Harris' 'Mia Young' 'Zoe Green'
#  'Robert King' 'Mia Allen' 'Ruby Green' 'Lucas Brown' 'Jack Scott'
#  'Ethan Parker' 'Daniel Lee' 'Lucas Young' 'Zoe Lee' 'Oscar Walker'
#  'Ruby Brown' 'Jack Taylor' 'Thomas Harris' 'Olivia White' 'Ethan White'
#  'Jack Walker' 'Samuel Lee' 'Grace White' 'James Anderson'
#  'Olivia Thompson' 'Emily Johnson' 'Robert Smith' 'Amelia Brown'
#  'Ava Robinson' 'Samuel Davis' 'Lily Wilson' 'Alexander Lewis'
#  'Chloe White' 'Daniel Walker' 'David Clark' 'Charlotte Miller'
#  'Joseph Carter' 'Sophie Wright' 'Isabella Scott' 'Thomas Mitchell'
#  'Henry Turner' 'Zoe Baker' 'Charles Lee' 'Ella Moore' 'Matthew Evans'
#  'Ethan Hall' 'Natalie Adams' 'George Allen' 'Madison King'
#  'Jack Campbell' 'Lily Nelson' 'Harrison Green' 'Charlotte Morgan'
#  'Lucy Hughes' 'Oliver Turner' 'Sofia Evans' 'Andrew Hill' 'Emma Ward'
#  'Grace Miller' 'Nathan Walker' 'Ella Carter' 'Isaac Scott' 'Leah Moore'
#  'Jack Robinson' 'Nora Mitchell' 'Zoe Bennett' 'Alexander Perry'
#  'Sophie Cox' 'Liam James' 'Samuel Martin' 'Daisy Roberts' 'Joshua Hill'
#  'Violet Foster' 'Matthew Sanders' 'Mia Clark' 'Thomas Fisher'
#  'Amelia Morris' 'William Evans' 'Harper Wells' 'Benjamin Ward'
#  'Ava Wright' 'Charlie Baker' 'Lucy Martin' 'Sophie Stevens' 'Max Lewis'
#  'Harper Bennett' 'Joseph Adams' 'Chloe Bennett' 'Michael Carter'
#  'Ella Griffin' 'Gabriel Young' 'Charlotte James' 'Anthony Clark'
#  'Olivia Robinson' 'Emily Phillips' 'Matthew Davis' 'Isla Parker'
#  'Sophia Allen' 'Liam Cooper' 'Lily Jackson' 'Harry Moore' 'Abigail Davis'
#  'Isaac Harris' 'Lucas Moore' 'Ruby Johnson' 'George Scott'
#  'Benjamin Phillips' 'Ella Rogers' 'Oliver Baker' 'Natalie Green'
#  'Jack Adams' 'Nicholas Lee' 'Emily Wright' 'Samuel Turner'
#  'Abigail Bennett' 'William Cooper' 'Ava Young' 'Emma Hill' 'Oliver Scott'
#  'Charlotte Adams' 'Alexander Taylor' 'Zoe Martin' 'Luke Robinson'
#  'Harper Lee' 'Leo Walker' 'Madison Brown' 'Violet Robinson' 'Liam Evans'
#  'Emma Cooper' 'Isabella Walker' 'Mia Evans']
# ===========================================================================
# columns: inc_state
# Unique Values:['Closed' 'In Progress' 'Canceled' 'New' 'On Hold']
# ===========================================================================
# columns: inc_cmdb_ci
# Unique Values:['GRP56.34 PRXX (DigitalC Workplace management)' nan
#  'ERP SFA SFS Finance Lev2 Support'
#  'NxGen TechServiceDesk-APAC-NonEnglish' 'Deskside-Tokyo-L1'
#  'ERP SFA Workflow' 'Authring PRXX' 'NxGen Chempost Errors'
#  'Office 365 Onedrive For Business'
#  'MVPTeMVPAzure Data Factory PRXX_MAVIS (Co - N)'
#  'Advanced Authentication' 'NxGen mwi b2b DTC_POVR - PRXX' 'SMQD SMS CH'
#  'Business Applications Tools' 'NxGen Citrix Cloud'
#  'NxGen RPA - Automation Anywhere' 'NxGen Citrix Cloud - US Dev'
#  'ERP SFA Op. Finance Lev2 Support'
#  'NxGen Ariba Guided Buying Container Application - PRXX'
#  'NxGen Global TeMVPService Desk' 'Email Services'
#  'Luminate Control Tower (LCT) - PRXX' 'MVPIndia - Freight'
#  'NxGen SailPoint (PRXX) IdentityNow' 'Expnce Expense Management'
#  'Deskside-Asia-House' 'ServiceNow' 'Printer / File Shre' 'Email-Outlook'
#  'NxGen PAM Delinea (PRXX) Privileged Access Security PAS'
#  'ERP SFA User Management' 'Deskside-Jamshoro-L1'
#  'MVPData Enablement - Data Management Platform - PRXX'
#  'NxGen RPA Platform PRXXuction' 'IM Ecrystal wrongly routed'
#  'Pulse Secure VPN/StaffConnect' 'Deskside-MountThomas-L1'
#  'Oracle Support - Asia'
#  'MVPTeMVPAzure Data Factory PRXX_Global (Co - Ba)' 'NxGen ERP SFA SQMC'
#  'MVPTeMVPAzure Analysis Services PRXX_MAVIS (Co - N)'
#  'NxGen Microsoft To-Do - PRXX' 'NxGen Global Digital Signature'
#  'Privilege Management Response Generator' 'Authring - PRXX (app service)'
#  'IM Ecrystal Application Issue' 'User Account Management'
#  'ERP SFA ABAP L3 Support' 'Centrify Service - PRXX'
#  'ERP SFA CF Volume Lev2 Support' 'NxGen Microsoft Office - PRXX'
#  'NxGen Business Applications Tools' 'Global TeMVPService Desk'
#  'ERP User Support' 'Nexota PC PRXXucts' 'MYLEARNING'
#  'ERP BISON Lev2 Support' 'NxGen ERP SFA CF Value Lev2 Support'
#  'ERP SFA PRXXuction Lev2 Support' 'Deskside-Tres-Cantos-L1' 'PC Hardware'
#  'Deskside-Bangalore' 'NxGen AD/ AAD' 'MVPChamps - PRXX'
#  'NxGen Hr OdS - PRXX' 'MAI - Aeon2 - PRXX' 'Directory Services'
#  'Connectivity Service' 'Microsoft Office' 'ABV Event - SFA Nixon'
#  'NxGen Expnce Expense Management - PRXX' 'Microsoft Powerautomate'
#  'single sign on (sso) PRXX' 'Edge' 'Oracle Support - Global'
#  'NxGen TechServiceDesk-EMEA' 'ERP SFA Procurement Lev2 Support'
#  'Deskside-Marisa' 'First SFA' 'Deskside-Peringan-L1'
#  'Local Area Network (LAN)' 'Consumer REPMSV Qualitydocs (PXX)'
#  'Vodafone mobile services' 'Deskside-Leon-L1'
#  'MVPIt Bi Compass Mds PRXXuction' 'Wireless' 'AppViewX CERT+ (PRXX)'
#  'ERP SFA Direct Procurement Lev2 Support' 'IND01wnpcyb0004'
#  'ERS &D - PSC Business Process' 'Digital Learning Service Team'
#  'Deskside-Poznan-Business-Garden-L1' 'NxGen Cadency' 'NxGen Oracle'
#  'MVPIndia - Sales Pricing' 'NxGen SiteOwner' 'nynsfp027' 'FileShare'
#  'Nexota - Jira Cloud' 'ERP SFA SFS Finance L3 Support' 'Cash Analytics'
#  'NxGen Ibm Mq (Test)' 'NxGen ERP SFA Security' 'Deskside-Dungarvan'
#  'Deskside-Athens' 'Deskside-Thailand' 'NxGen File Sharing'
#  'IND01iskdc1900' 'Deskside-Moscow-L1'
#  'NxGen Adobe Acrobat Standard\\Professional' 'Process Reorder Service'
#  'ERP SFA Serialisation Lev2 Support' 'Deskside-DubaiArenco'
#  'ERP SFA Op. Finance L3 Support' 'Windows 10 Os'
#  'IM Ecrystal Infrastructure Issue' 'NxGen Oracle - PRXX'
#  'ERP SFA Security' 'Authentication' 'ERP SFA Basis PRXX Support'
#  'Chrd REPMSV Promomats' 'NxGen Microsoft O365 OneDrive For Business'
#  'Deskside-Prague-L1' 'Deskside-Maidenhead-L1'
#  'ERP Access Issues & Queries'
#  'MVPTeMVPAzure Data Lake Store PRXX_Global (Co - Ba)'
#  'SMQD SMS MVP(PRXX)'
#  'NxGen Azure DevOps Services - DevOps-CH-Americas-Analytics'
#  'NxGen Ariba Guided Buying Container Application' 'NxGen Adobe Sign'
#  'File Share Registration System [Tbc]' 'Internet Explorer - P000258320'
#  'Backup and Recovery' 'SED PRXX (secondary enterprise directory)'
#  'iaymfp013' 'iaymfp017' 'iaymfp025' 'Cap - Seaserver - PRXX'
#  'IM Ecrystal ABV Citrix Infrastructure Issue' 'NxGen MVPChamps'
#  'barmfp013' 'End to End Serialisation Services'
#  'NxGen Citrix Cloud - UK / US PRXX'
#  'NxGen Adobe Creative Cloud Desktop App' 'NetworkAdapter@unknown'
#  'Deskside-India-Gurgaon' 'Dungarvan - Deskside - IT' 'Software Center'
#  'Servicenow PRXX' 'Merp2 App' 'NxGen Expnce Expense Management'
#  'Deskside-Cairo' 'NxGen SFA BW - PRXX'
#  'ERP SFA Ringside Sales  Lev2 Support' 'Microsoft Store'
#  'Dungarvan Automation - SO' 'NxGen Broadcast' 'buamfp042'
#  'IND01awnmw0101' 'myLearning PSC Training Management' 'Email-POD'
#  'Password Portal PRXX Application' 'ERP SFA QM Lev2 Support'
#  'MVPTeMVPPower Bi PRXXuction' 'NxGen myPSR' 'wifitest'
#  'Device deployment ' 'volume_1' 'NxGen Goanywhere PRXX'
#  'NxGen Goanywhere Test' 'Proofpoint Email' 'Deskside-Levice-L1'
#  'ERP SFA Warehousing L3 Support' 'MVPGLMSODS  PRXX' 'MVPGLMSODS TEST'
#  'SLIMS - PRXX' 'Windows 10 Image Installation' 'workers-sg'
#  'NxGen Global Employee Recognition  - PRXX' 'Pgg - Pas-X - Dev'
#  'Deskside-missisuaga-L1' 'ERP SFA Warehousing Lev2 Support'
#  'IM Ecrystal Network Issue' 'Slims-MVP(Retired)' 'pznmfp002'
#  'Deskside-Baranzate' 'Deskside-Alcala' 'Deskside-Nairobi-L1'
#  'Guayama Site Local SLIMS LAB : S074359865'
#  'ERP SFA CF Volume L3 Support' 'Leaving ABV - Global'
#  'gpp-ws-appsvc-PRXX-eus-01' 'DataServices' 'NxGen Netdocuments - PRXX'
#  'Exchange Online' 'NxGen Microsoft O365 SharePoint'
#  'Deskside-Warsaw-Cirrus-L1' 'Deskside-Santiago-L1'
#  'EPM - Windows Client Agent' 'Deskside-Lincoln-L1' 'Microsoft Teams'
#  'PC Build' 'MVPDam Streamline Application' 'Deskside-Chennai-L1'
#  'Access Control System - Nairobi'
#  'Crms Consumer Relations Management System - PRXX'
#  'Appspace Digital Signage Consumer Healthcare' 'vpnNwTest' 'pggmfp031'
#  'Pas-X EBRS' 'pggmfp027' 'NxGen New Fileshare' 'pggmfp002'
#  'NxGen IBM SCBN - PRXX' 'Cap - Pas-X - PRXX'
#  'NxGen TechServiceDesk-LATAM' 'NxGen TechServiceDesk-Global-English'
#  'CRS (Customer Relation Services) BT Telephony - SO' 'NxGen SFA BW - Dev'
#  'First SFA Sample Module (GxP)'
#  'Perimeter Security & Compliance - Service Offering' 'lenmfp030'
#  'ERP SFA Portal Lev2 Support' 'Secure File Transfer SaaS' 'buamfp003'
#  'Guayama Site Local ONECDS LAB : S074359866'
#  'NxGen Gerp Qlik Sense Application  - Dev' 'Procurement' 'PF2R9CQ8'
#  '5CG8282D3W' 'APOLLO OTIF' 'Stibo MDM - PRXXuct (GxP)' 'cuemfp002'
#  'Cryptographic Key Service' 'NxGen Apigee PRXX' 'Pc Admin Rights'
#  'Deskside-Civac' 'US - MVPExpert CRM Service' 'HR for Employees'
#  'Pgg - Acronis Image 2 Business Application : S237674610'
#  'Stibo MDM - PIM Syndication' 'RRONE Business Application : P055599681'
#  'Guayama Site Local LAB : S074358036'
#  'NxGen mwi b2b app connect professional - PRXX' 'NxGen Cadency - PRXX'
#  'Deskside-Noida-L1' 'IND01aldIND0101' 'ERP SFA TSM Support'
#  'NxGen Oracle Security' 'Pas-X - Guayama Ebr System' 'Deskside-CapeTown'
#  'Pgg - Pas-X - PRXX' 'MVPCompass Service' 'Deskside-TerraCampus-L1'
#  'Deskside-Panama-L1' 'Ariba Queries' 'Microsoft Project Online'
#  'Support TSK' 'ERP SFA Ringside Sales  L3 Support' 'Deskside-Lima-L1'
#  'FSO-Dispatch' 'CMMS EAM MVPPRXX' 'Workstation EPM'
#  'ERP SFA Basis Non-PRXX Support' 'CrowdStrike' 'Sharepoint Onprem'
#  'First SFA (excluding Sample Module)' 'Safari Mobile'
#  'Deskside-Nagpur-L1' 'NxGen Ariba Sourcing - PRXX'
#  'SMBO ServiceNow Ecrystal Triage' 'IM Ecrystal Printing Issue'
#  'hcmmfp009' 'Global ERP Service Management'
#  'MVPRMS Dashboard- PRXXuction' 'Purchase to Pay Help'
#  'Azure Analytics Quality Dashboard PRXX' 'Luminate Control Tower (LCT)'
#  'Deskside-Seoul-L1' 'Apollo OTIF' 'SFA ASCS60 on SLP'
#  'Cadency Journals for Non Finance Users and COPA Journals' 'ucmsxve004'
#  'ERP SFA Procurement L3 Support' 'IND01wndclc0981.ad.Svcnet.org'
#  'Deskside-Istanbul-L1' 'NxGen VMware Workspace One'
#  'NxGen Privileged Access Management (PAM) Service'
#  'NxGen CGIT SailPoint IdentityNow SaaS Business Application'
#  'IAM Portal PRXX' 'NxGen Microsoft Teams Application' 'Onenote'
#  'Password Portal QA' 'ERP SFA Direct Procurement L3 Support'
#  'csbspwn00002' 'NxGen Interflex - Switzerland - PRXX Environment'
#  'NxGen Meeting Manager - PRXX' 'NxGen StealthAudit' 'NxGen Network'
#  'NxGen ERP SFA TSM Support' 'NxGen New Azure Subscription'
#  'IND02-PXX-peri-vmss-green'
#  'MVPTeMVPAzure Data Bricks PRXX_MAVIS (Co - N)'
#  'SFA Fieldglass-Internal Tech' 'ch-corp-devtest-IND01-sql-rg01']
# ===========================================================================
# columns: inc_caller_id
# Unique Values:['Event Management ' 'Cross-Connect  svc' 'ITSM-PO Functional']
# ===========================================================================
# columns: inc_short_description
# Unique Values:['Monitor status is error for ukwwnppcm0981_[PCM_US_PRXX]_error_in_logfile'
#  'IND01PXXRBK01: NBR: OracleDb:Backup : Status: 300 - 02/10/18 19:55:00 EDT'
#  'IND01PXXRBK01: SLQ: OracleDb:Backup : Status: 300 - 02/10/18 20:15:00 EDT'
#  ... "Error reported by alert rule 'AR_C118'"
#  "Error reported by alert rule 'AR_C119'"
#  "Error reported by alert rule 'AR_C83'"]
# ===========================================================================
# columns: inc_assignment_group
# Unique Values:['EngineeringSystems-Lev2' 'Bakup_Tek-SVC-Lev2' 'InfraWind-SVC-Lev2'
#  'SFA-SFS-Finance-Lev2' 'TechServiceDesk-APAC-NonEnglish-L1'
#  'Deskside-Tokyo-L1' 'SFA-Workflow-Lev2' 'AdvancedAuthentication-Lev2'
#  'RPABotSupport-Lev2-L3' 'BusinessIntelligence-Lev2'
#  'MWB2B-DTC_POVR-Lev2-L3' 'NxGen-CloudDatabaseSQL-SVC-Lev2'
#  'QualityApplications-Lev2' 'Infra_Unix-SVC-Lev2'
#  'O365PRXXuctivityBusinesSFAps-Lev2' 'Global-Citrix-Lev2' 'RPA-Lev2-L3'
#  'NetTool-Lev2' 'Ariba-Expnce-Lev2' 'OfficeSuiteApplications-Lev2'
#  'CH-E2EVisibility-DevOps-Applications-Lev2' 'ISC-LocalAppSupport-Lev2'
#  'Access-Governance-Lev2' 'Expnce-Cognos-Lev2' 'Deskside-Asia-House-L1'
#  'SMBOPlatform-Delinea' 'Privileged-Access-Admin-Lev2'
#  'SFA-UserManagement-Lev2' 'Deskside-Jamshoro-L1'
#  'CH-DataAnalyticsTeam-Lev2' 'TechServiceDesk-Global-English-L1'
#  'Deskside-MountThomas-L1' 'ABV-SN-Ecrystal-IMTransfer' 'SFA-SQMC-Lev2'
#  'TechServiceDesk-EMEA-L1' 'O365Collaboration-Lev2'
#  'DigitalSignature-Lev2' 'SFA-ABAP-L3' 'DirectoryServices-Lev2'
#  'SFA-CF-Volume-Lev2' 'SFA-SalesDistribution-Lev2' 'Deskside-Leon-L1'
#  'SFA-BISON-Lev2' 'EmailServices-Lev2' 'SFA-CF-Value-Lev2'
#  'SFA-PRXXuction-Lev2' 'UserAccount-Lev2' 'Deskside-Tres-Cantos-L1'
#  'ADInfrastructure-Lev2' 'NPIPackPortfolio-CHAMPS-Lev2'
#  'CorpTech-HRDataManagement-Lev2' 'MaidenheadLocalSite-Lev2'
#  'SFA-Basis-PRXX-Lev2-L3' 'GlobalOracle-Lev2' 'SFA-Procurement-Lev2'
#  'myLearning-Lev2' 'Deskside-Marisa-L1' 'First-SFA-Lev2'
#  'Deskside-Peringan-L1' 'VoiceMobileUK-Lev2' 'CryptographicKey-Lev2'
#  'SFA-Direct-Procurement-Lev2' 'SCS-SupplyChain-L1'
#  'L&D-Digital-Learning-Services-Lev2' 'Deskside-Poznan-Business-Garden-L1'
#  'CorpTech-FinProc-Lev2' 'GlobalOracle-L3' 'RicohSupport-Lev2'
#  'CH-TechTooling-Lev2' 'SFA-SFS-Finance-L3' 'MW-Lev2-L3'
#  'SFA-Security-Lev2' 'Deskside-Dungarvan-L1' 'Deskside-Athens-L1'
#  'Deskside-Thailand-Bangkok-L1' 'FileSharing-Lev2' 'Deskside-Moscow-L1'
#  'AdobeCloud-Lev2' 'SFA-PI-PO-Lev2' 'SFA-Serialisation-Lev2'
#  'Deskside-DubaiArenco-L1' 'SFA-Op.Finance-L3' 'Deskside-Pulogadung-L1'
#  'SFA-Basis-Non-PRXX-Lev2-L3' 'ContentExcellence-Promomats-Lev2'
#  'Deskside-Prague-L1' 'Deskside-Maidenhead-L1' 'FIN-ERP-Access-Global'
#  'Ariba-L3' 'TechServiceDesk-LATAM-L1' 'TrackTracePRXXuct-Lev2'
#  'PrintSupport-Lev2' 'SCS-Serialisation-Lev2-L3'
#  'Deskside-India-Gurgaon-L1' 'LabEngineering-DLS'
#  'PC-AppCatalogInstall-Lev2' 'SMBOPlatform-Core-Lev2'
#  'Deskside-Bangalore-L1' 'Expnce-L3' 'SFA-BW-Lev2'
#  'Dungarvan-Automation-Lev2' 'Deskside-Budapest-L1'
#  'SCS-DocMgt-Training-L1' 'SFA-QM-Lev2' 'NPIPackPortfolio-myPSR-Lev2'
#  'Deskside-Karachi West Wharf-L1' 'CH-CyberDefense-L1'
#  'Deskside-Levice-L1' 'SFA-Warehousing-L3' 'LabOperations-Lev2'
#  'SFA-Op.Finance-Lev2' 'Deskside-Buenos-Aires-L1'
#  'CorpTech-HRBenefitServices-Lev2' 'GuayamaLocalSite-Lev2'
#  'Deskside-Brazil-LeMonde-L1' 'SFA-Warehousing-Lev2'
#  'GuayamaLocalSiteSLIMS-Lev2' 'Deskside-Baranzate-L1' 'Deskside-Alcala-L1'
#  'Deskside-Nairobi-L1' 'SFA-CF-Volume-L3' 'CH-E2EVisibility-LCT'
#  'CorpTech-Legal-Support-Lev2' 'Deskside-Warsaw-Cirrus-L1'
#  'Deskside-Santiago-L1' 'PC-EPM-and-Policy-Lev2' 'Deskside-Lincoln-L1'
#  'Collaboration-Lev2' 'ContentExcellence-Streamline-Lev2'
#  'Deskside-Chennai-L1' 'ConsumerRelationsManagement-Lev2' 'Broadcast-Lev2'
#  'Deskside-Guayama-L1' 'PC-Build-Lev2' 'MWB2B-GXS-Lev2-L3'
#  'ManufacturingExecution-Lev2' 'CRS-BT-Telephony-Lev2' 'SFA-BW-L3'
#  'SFA-Portal-Lev2' 'CH-Roger-Lev2' 'SecureFileTransfer-Lev2'
#  'GuayamaLocalSiteOCDS-Lev2' 'AnalyticsBi-Lev2-L3' 'CHMDM-Lev2'
#  'SMBOPlatform-RequestManagement-Lev2' 'SFA-TSM' 'CH-CyberDefense-Lev2'
#  'CHAPIApigee-Lev2' 'PC-PRXXucts-Lev2' 'Deskside-Civac-L1'
#  'ExpertOps-US-Lev2' 'MWB2B-AppConnect-Lev2-L3'
#  'GlobalOracle-Security-Lev2' 'Deskside-CapeTown-L1'
#  'BusinessIntelligenceSyndicate-Lev2' 'Deskside-TerraCampus-L1'
#  'First-SFA-L3' 'Deskside-Panama-L1' 'Deskside-Mexico-Artz-L1'
#  'SFA-SalesDistribution-L3' 'Deskside-Lima-L1' 'FSO-Dispatch-L1'
#  'WebHosting-Lev2' 'MobileDeviceMgt-Lev2' 'Deskside-Nagpur-L1'
#  'CommandCenter-MIMTech' 'SFA-ServiceMgmt-L3' 'Deskside-Seoul-L1'
#  'Cloud Edge-Infra-SVC-Lev2' 'FIN-CC-Cadency-ABVOps-Global'
#  'SFA-Procurement-L3' 'Deskside-Istanbul-L1' 'RF-Gun-Lev2'
#  'Access-Governance-L3' 'SFA-Direct-Procurement-L3'
#  'EnterpriseComputingWindows-Lev2' 'LeonLocalSite-Lev2'
#  'CorpTech-WMAS-Lev2' 'ExecutiveTechSupport-Lev2'
#  'FIN-FSSC-HelpDesk-Russia' 'SFA-Fieldglass-Internal-Tech-Lev2']
# ===========================================================================
# columns: inc_close_code
# Unique Values:['3rd Party Issue' 'Other not on list' 'No Fault Found'
#  'Configuration Change' 'User Education and Training' 'User Hardware' nan
#  'Network Issue' 'Solved Remotely (Permanently)' 'User Resolved'
#  'Infrastructure Hardware' 'Data Issue'
#  'Customer/Cancelled Fault Report/Duplicate Case' 'Power Issue'
#  'Duplicate Ticket' 'Solved (Permanently)' '3 Strike Policy'
#  'Capacity Issue' 'False Alarm' 'PRXXuct defect / error'
#  'Process defect / not followed' 'PRXXuct Issue due to Age']
# ===========================================================================
# columns: inc_close_notes
# Unique Values:['Covered in Problem management. ' 'Resolving from CliqApps' nan ...
#  'The XML message has been processed successfully, no action pending from our end. Hence we are closing the ticket.'
#  'Resolution:_x000D_\nThis issue has been raised with Tungsten team and the same is being worked upon via Tungsten remedy number, 2305371._x000D_\n'
#  'we do not see the message id in SFA hence we are closing the ticket _x000D_\nit isay "No messages found"']
# ===========================================================================

# %%
for col in df.columns:
    unique_values = df[col].nunique()
    print(f"columns: {col}")
    print(f"Unique Values:{unique_values}")
    print("==="*25)
# Out:
# columns: inc_business_service
# Unique Values:202
# ===========================================================================
# columns: inc_category
# Unique Values:9
# ===========================================================================
# columns: inc_number
# Unique Values:1870
# ===========================================================================
# columns: inc_priority
# Unique Values:4
# ===========================================================================
# columns: inc_sla_due
# Unique Values:1
# ===========================================================================
# columns: inc_sys_created_on
# Unique Values:1676
# ===========================================================================
# columns: inc_resolved_at
# Unique Values:1821
# ===========================================================================
# columns: inc_assigned_to
# Unique Values:456
# ===========================================================================
# columns: inc_state
# Unique Values:5
# ===========================================================================
# columns: inc_cmdb_ci
# Unique Values:304
# ===========================================================================
# columns: inc_caller_id
# Unique Values:3
# ===========================================================================
# columns: inc_short_description
# Unique Values:1493
# ===========================================================================
# columns: inc_assignment_group
# Unique Values:181
# ===========================================================================
# columns: inc_close_code
# Unique Values:21
# ===========================================================================
# columns: inc_close_notes
# Unique Values:1029
# ===========================================================================

# %%
df.isnull().sum()
# Out:
# business_service     0
# category             0
# priority             0
# sys_created_on       0
# resolved_at          0
# assigned_to          0
# state                0
# cmdb_ci              0
# caller_id            0
# short_description    0
# assignment_group     0
# close_code           0
# close_notes          0
# dtype: int64

# %%
df.columns = df.columns.str.replace("inc_","",case=False)

# %%
# Remove two columns which are not required 
df = df.drop(columns=["sla_due","number"])

# %%
# conversion of datetime datatype
df["sys_created_on"] = pd.to_datetime(df["sys_created_on"])
df["resolved_at"] = pd.to_datetime(df["resolved_at"])

# %%
# impute missing timing 

df["resolution_time"] = (df["resolved_at"] - df["sys_created_on"]).dt.total_seconds()
avg_resolution_time = df["resolution_time"].mean()

df.loc[df["resolved_at"].isnull(),"resolved_at"] = df["sys_created_on"] + pd.to_timedelta(avg_resolution_time,unit = "s")

# %%
# impute missing for cmdb_ci
df["cmdb_ci"] = df.groupby("category")["cmdb_ci"].transform(lambda x : x.fillna(x.mode()[0]) if not x.mode().empty else "Unknown")

# %%
df["short_description"] = df["short_description"].fillna(df["short_description"].mode()[0])

# %%
df["close_code"] = df.groupby("assignment_group")["close_code"].transform(lambda x : x.fillna(x.mode()[0]) if not x.mode().empty else "Unknown")

# %%
df["close_notes"] = df.groupby("close_code")["close_notes"].transform(lambda x : x.fillna(x.mode()[0]) if not x.mode().empty else "Unknown")

# %%
df.drop(columns=["resolution_time"],inplace = True)

# %%
df.to_excel("handeled_missing.xlsx",index = False)
